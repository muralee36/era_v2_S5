# %% [markdown]
# Imports

# %%
# imports
import importlib
import utils
import matplotlib.pyplot as plt
import model
import torch

importlib.reload(utils)
importlib.reload(model)
# Out:
# <module 'model' from '/content/model.py'>

# %% [markdown]
# Train and Test Data

# %%
train_data, test_data = utils.get_test_train_data()
train_loader, test_loader = utils.test_train_data_loader(train_data, test_data, 512)

# %% [markdown]
# Plotting data

# %%
batch_data, batch_label = next(iter(train_loader))

fig = plt.figure()

for i in range(12):
  plt.subplot(3,4,i+1)
  plt.tight_layout()
  plt.imshow(batch_data[i].squeeze(0), cmap='gray')
  plt.title(batch_label[i].item())
  plt.xticks([])
  plt.yticks([])

# %% [markdown]
# Model Training and testing

# %%
model.start_model_train_and_test(train_loader, test_loader)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 26, 26]             320
#             Conv2d-2           [-1, 64, 24, 24]          18,496
#             Conv2d-3          [-1, 128, 10, 10]          73,856
#             Conv2d-4            [-1, 256, 8, 8]         295,168
#             Linear-5                   [-1, 50]         204,850
#             Linear-6                   [-1, 10]             510
# ================================================================
# Total params: 593,200
# Trainable params: 593,200
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.67
# Params size (MB): 2.26
# Estimated Total Size (MB): 2.94
# ----------------------------------------------------------------
# None
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 1
# Train: Loss=2.2388 Batch_id=19 Accuracy=17.26: 100%|██████████| 20/20 [00:54<00:00,  2.74s/it]
# Test set: Average loss: 2.2385, Accuracy: 21615/60000 (36.02%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 2
# Train: Loss=0.8358 Batch_id=19 Accuracy=54.85: 100%|██████████| 20/20 [00:56<00:00,  2.83s/it]
# Test set: Average loss: 1.3858, Accuracy: 34745/60000 (57.91%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 3
# Train: Loss=2.2688 Batch_id=19 Accuracy=29.55: 100%|██████████| 20/20 [00:53<00:00,  2.68s/it]
# Test set: Average loss: 2.2674, Accuracy: 15483/60000 (25.80%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 4
# Train: Loss=2.0249 Batch_id=19 Accuracy=32.64: 100%|██████████| 20/20 [00:53<00:00,  2.67s/it]
# Test set: Average loss: 2.0193, Accuracy: 19774/60000 (32.96%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 5
# Train: Loss=2.3183 Batch_id=19 Accuracy=59.56: 100%|██████████| 20/20 [00:56<00:00,  2.83s/it]
# Test set: Average loss: 5.1028, Accuracy: 28913/60000 (48.19%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 6
# Train: Loss=0.7986 Batch_id=19 Accuracy=58.55: 100%|██████████| 20/20 [00:54<00:00,  2.74s/it]
# Test set: Average loss: 0.9044, Accuracy: 42248/60000 (70.41%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 7
# Train: Loss=0.3220 Batch_id=19 Accuracy=84.90: 100%|██████████| 20/20 [00:54<00:00,  2.72s/it]
# Test set: Average loss: 0.5078, Accuracy: 50877/60000 (84.80%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 8
# Train: Loss=0.2233 Batch_id=19 Accuracy=92.13: 100%|██████████| 20/20 [00:51<00:00,  2.59s/it]
# Test set: Average loss: 0.3850, Accuracy: 53025/60000 (88.38%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 9
# Train: Loss=0.1664 Batch_id=19 Accuracy=93.89: 100%|██████████| 20/20 [00:51<00:00,  2.60s/it]
# Test set: Average loss: 0.3441, Accuracy: 53752/60000 (89.59%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 10
# Train: Loss=0.1766 Batch_id=19 Accuracy=95.06: 100%|██████████| 20/20 [00:51<00:00,  2.59s/it]
# Test set: Average loss: 0.3060, Accuracy: 54404/60000 (90.67%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 11
# Train: Loss=0.1749 Batch_id=19 Accuracy=95.82: 100%|██████████| 20/20 [00:52<00:00,  2.60s/it]
# Test set: Average loss: 0.2741, Accuracy: 55075/60000 (91.79%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 12
# Train: Loss=0.1511 Batch_id=19 Accuracy=96.43: 100%|██████████| 20/20 [00:51<00:00,  2.59s/it]
# Test set: Average loss: 0.2757, Accuracy: 55058/60000 (91.76%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 13
# Train: Loss=0.1394 Batch_id=19 Accuracy=96.75: 100%|██████████| 20/20 [00:53<00:00,  2.65s/it]
# Test set: Average loss: 0.2370, Accuracy: 55819/60000 (93.03%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 14
# Train: Loss=0.0587 Batch_id=19 Accuracy=97.19: 100%|██████████| 20/20 [00:53<00:00,  2.67s/it]
# Test set: Average loss: 0.2393, Accuracy: 55786/60000 (92.98%)
#
# Adjusting learning rate of group 0 to 1.0000e-02.
# Epoch 15
# Train: Loss=0.0845 Batch_id=19 Accuracy=97.66: 100%|██████████| 20/20 [00:52<00:00,  2.62s/it]
# Test set: Average loss: 0.2559, Accuracy: 55712/60000 (92.85%)
#
# Adjusting learning rate of group 0 to 1.0000e-03.
# Epoch 16
# Train: Loss=0.0816 Batch_id=19 Accuracy=97.75: 100%|██████████| 20/20 [00:51<00:00,  2.59s/it]
# Test set: Average loss: 0.2263, Accuracy: 56018/60000 (93.36%)
#
# Adjusting learning rate of group 0 to 1.0000e-03.
# Epoch 17
# Train: Loss=0.0547 Batch_id=19 Accuracy=98.05: 100%|██████████| 20/20 [00:52<00:00,  2.60s/it]
# Test set: Average loss: 0.2177, Accuracy: 56202/60000 (93.67%)
#
# Adjusting learning rate of group 0 to 1.0000e-03.
# Epoch 18
# Train: Loss=0.0760 Batch_id=19 Accuracy=98.09: 100%|██████████| 20/20 [00:52<00:00,  2.60s/it]
# Test set: Average loss: 0.2180, Accuracy: 56220/60000 (93.70%)
#
# Adjusting learning rate of group 0 to 1.0000e-03.
# Epoch 19
# Train: Loss=0.0806 Batch_id=19 Accuracy=98.11: 100%|██████████| 20/20 [00:52<00:00,  2.61s/it]
# Test set: Average loss: 0.2180, Accuracy: 56233/60000 (93.72%)
#
# Adjusting learning rate of group 0 to 1.0000e-03.
# Epoch 20
# Train: Loss=0.0605 Batch_id=19 Accuracy=98.09: 100%|██████████| 20/20 [00:52<00:00,  2.63s/it]
# Test set: Average loss: 0.2172, Accuracy: 56246/60000 (93.74%)
#
# Adjusting learning rate of group 0 to 1.0000e-03.
